# %% [markdown]
# <a href="https://colab.research.google.com/github/fathillahdarojad/kka-semester-1/blob/main/tipe_variabel_fathillahAD_XI_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# nama: fathillah Akbar Darojad
# kelas: XI. 1
# No. abs:11

# %% [markdown]
# #konsep dasar

# %%
email_user_1 = "fathillahakbardarojad@gmail.com"


print(email_user_1)
# Out:
# fathillahakbardarojad@gmail.com

# %%
sabun_indomaret = 2000
print(sabun_indomaret)
# Out:
# 2000

# %%
print(sabun_indomaret*3)
# Out:
# 6000

# %% [markdown]
# #peraturan penulisan variabel

# %%
#penulisan variabel hanya boleg menggunakan huruf, angka, dan underscore
# tidak boleh mengunakan spasi
nama siswa ="afa"
print(nama siswa)
# Out:
#   File "/tmp/ipython-input-2357104854.py", line 3
#     nama siswa ="afa"
#          ^
# SyntaxError: invalid syntax

# %%
#tidak boleh di awali dengan angka
1_nama_siswa = "afa"

print(1_nama_siswa)
# Out:
#   File "/tmp/ipython-input-2575385211.py", line 2
#     1_nama_siswa = "afa"
#      ^
# SyntaxError: invalid decimal literal

# %%
#penulisan variabel itu case sensitive
nama_siswa_1 = "afa"

print(Nama_siswa_1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1641735940.py in <cell line: 0>()
#       2 nama_siswa_1 = "afa"
#       3
# ----> 4 print(Nama_siswa_1)
#
# NameError: name 'Nama_siswa_1' is not defined

# %%
#dilarang mengunakan kata kunci bahasa Python
prin = "afa"

print(prin)
# Out:
# afa

# %%
end = "naufal"
print(end)
# Out:
# naufal

# %%
#deskrip
_ = "favian"
print (_)
# Out:
# favian

# %%
#tidak boleh pakai kata kunci python
#kalau eror, harus dc dlu
#print = "devin"

#print (print)

# %% [markdown]
# #ASSIGNMENT

# %% [markdown]
# ##single assignment

# %%
nama_siswa_2 = "lek toyo"
nama_siswa_3 = "gunawan"

print(nama_siswa_2)
print(nama_siswa_3)
# Out:
# lek toyo
# gunawan

# %% [markdown]
# ##multiple assignment

# %%
nama_siswa_4, nama_siswa_5 = "sada", "dapin"
print(nama_siswa_4)
print(nama_siswa_5)
# Out:
# sada
# dapin

# %% [markdown]
# #aritmatika

# %%
print("5000*3")
# Out:
# 5000*3

# %%
#operand tanpa di simpan dalam variabel
print(5000*3)
# Out:
# 15000

# %%
#simpan operand dalam variabel
harga_total_kojek = 3000*3
print(harga_total_kojek)
# Out:
# 9000

# %%
#Simpan nilai operand dan hasil operasi ke dalam variabel

harga_cilok = 10000

jumlah_porsi_cilok = 5

harga_total_cilok = harga_cilok*jumlah_porsi_cilok

print(harga_total_cilok)
# Out:
# 50000

# %%
uang_yang_diterima = 100000

uang_kembalian = uang_yang_diterima - harga_total_cilok

print(uang_kembalian)
# Out:
# 50000

# %%
print(24*3)
# Out:
# 72

# %%
total_jumlah_botol = 24*3
print(total_jumlah_botol)
# Out:
# 72

# %%
banyak_botol_perkardus = 24
jumlah_kardus = 3
print(banyak_botol_perkardus*jumlah_kardus)
# Out:
# 72

# %%
banyak_botol_perkardus = 24
jumlah_kardus = 3

jumlah_total_botol = banyak_botol_perkardus*jumlah_kardus
print (jumlah_total_botol)
# Out:
# 72

# %% [markdown]
# #tipe variabel

# %%
usia = 65
type(usia)
# Out:
# int

# %%
berat_telur = 1.5
type(berat_telur)
# Out:
# float

# %%
nama = "dapin"
type(nama)
# Out:
# str

# %%
remidi = False
type(remidi)
# Out:
# bool

# %%
kordinat_bintang = -1.69
type(kordinat_bintang)
# Out:
# float

# %%
kordinat = -8
type(kordinat)
# Out:
# int

# %%
p = 10
l = 3
L = p*l
print(L)
# Out:
# 30

# %%
input()
# Out:
# 10
# '10'

# %%
panjang = input()
# Out:
# 10

# %%
print(panjang)
# Out:
# 10

# %%
lebar = input()
# Out:
# 3

# %%
print(lebar)
# Out:
# 3

# %%
print(panjang*lebar)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-456381395.py in <cell line: 0>()
# ----> 1 print(panjang*lebar)
#
# NameError: name 'panjang' is not defined

# %%
type(panjang)
# Out:
# str

# %%
type(lebar)
# Out:
# str

# %%
panjang = int(panjang)
lebar = int(lebar)
type(panjang)
# Out:
# int

# %%
panjang_1 = int(input("Masukkan panjang persegi: "))
# Out:
# Masukkan panjang persegi: 10

# %%
panjang_2 = int(input("Masukkan panjang persegi: "))

lebar_2 = int(input("Masukkan lebar persegi: "))

luas_2 = panjang_2*lebar_2

print(f"Luas persegi panjang adalah {luas_2} cm^2")
# Out:
# Masukkan panjang persegi: 10
# Masukkan lebar persegi: 3
# Luas persegi panjang adalah 30 cm^2

# %%
p = int(input("Masukkan panjang (dalam cm): "))
l = int(input("Masukkan lebar (dalam cm): "))
t = int(input("Masukkan tinggi (dalam cm): "))


V = p * l * t

print(f"Volume balok adalah: {V} cm³")
# Out:
# Masukkan panjang (dalam cm): 1
# Masukkan lebar (dalam cm): 2
# Masukkan tinggi (dalam cm): 3
# Volume balok adalah: 6 cm³

# %%
print(8<5)
# Out:
# False

# %%
print(8>5)
# Out:
# True

# %%
print(9>=9)
# Out:
# True

# %%
print(8 == 5)
# Out:
# False

# %%
print(8==8)
# Out:
# True

# %%
print(1 != 1)
# Out:
# False

# %%
a = 10

b = 20

c = 30

print(a>c)
# Out:
# False

# %%
print(a>30)
# Out:
# False

# %%
nilai_kka = 75

kkm_kka = 80

print(nilai_kka > kkm_kka)
# Out:
# False

# %%
print(8>7 and 5>6)
# Out:
# False

# %%
print(8>7 and 5<6)
# Out:
# True

# %%
print(8>7 or 5>6)
# Out:
# True

# %%
print(not (8>7 or 5>6))
# Out:
# False

# %%
print(not (8>=9 or 9!=8))
# Out:
# False

# %%
iq_min = 125

tinggi_min = 165

print(125 >=iq_min and 170 >= tinggi_min)
# Out:
# True

# %%
iq_afa = 125

tinggi_afa = 170

print(iq_afa >= iq_min and tinggi_afa >= tinggi_min)
# Out:
# True

# %%
tinggi = 170
berat = 55
umur = 23

if tinggi >= 165 and berat >= 50 and umur <= 25:
    print("Lulus pendaftaran taruna")
else:
    print("Tidak lulus pendaftaran taruna")
# Out:
# Lulus pendaftaran taruna

# %%
Tinggi_minimal = 165

Berat_badan_minimal = 55
umur_max = 25

# %%
tinggi_farel = 170
berat_farel = 55
umur_farel = 23
print(tinggi_farel>=Tinggi_minimal and Berat_badan_minimal>=berat_farel and umur_max>=umur_farel)
# Out:
# True
